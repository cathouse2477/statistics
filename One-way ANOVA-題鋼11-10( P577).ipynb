# %%
<font size="4" color="BLUE"> 題網 範例11.10 p577</font></br>
![test](https://github.com/cathouse2477/statistics/blob/main/%E9%A1%8C%E7%B6%B111.10%20p577.jpg)
<img src="https://github.com/cathouse2477/statistics/blob/main/%E9%A1%8C%E7%B6%B111.10%20p577.jpg" width="48">

# %% [markdown]
# <font size="5" color="orange">變異數同質</font>

# %%
import pandas as pd
import numpy as np
from scipy.stats import levene
from scipy.stats import f_oneway
#Create samples
df = pd.DataFrame({
    "低速":[47,43,45,44,46],
    "中速":[44,43,41,40,42],
    "高速":[39,34,38,34,35]
})
#levene's test
statistic, p_value=levene(df["低速"], df["中速"], df["高度"])
print('statistic:%.2f'%statistic)
print('p_value:%.2f'%p_value)
# Out:
# statistic:1.92
# p_value:0.15

# %% [markdown]
# <font size="4" color="red">根據結果，發現同質性檢結果不顯著(p>.05)，因此可以接續進行Anova檢定：</font>

# %%
f_statistic, p_value = f_oneway(df["A班"], df["B班"], df["C班"])
print("f_statistic:%.2f"%f_statistic)
print("p_value:%.2f"%p_value)
# Out:
# f_statistic:3.92
# p_value:0.02

# %% [markdown]
# <font size="4" color="red">ANOVA（變異數分析）檢定多個樣本變異數的同質性，主要看的是「組間變異」與「組內變異」的比例，目的是判斷多組樣本的平均數是否有顯著差異，而不是直接檢定變異數本身，常用的檢定變異數同質性（Homogeneity of Variances）的方法有 Levene's Test（推薦）和 Bartlett's Test，若變異數不具同質性，則需考慮使用Welh's ANOVA。</font>

# %% [markdown]
# <font size="4" color="blue">這裡一樣我們關注p值，所以根據結果，發現呈顯著差異(p>.05)，代表三個班級的成績，擁有明顯的差異。不過到這裡一定會好奇，既然有顯著差異，那到底是哪一班的成績比較突出一點？或是是比較差？這時就可以進行事後檢定(Post-hoc)，來幫我們探知一切：</font>

# %%
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
#轉換資料格式
new_df = pd.melt(df, var_name="組別", value_name="成績")
posthoc = pairwise_tukeyhsd(new_df["成績"], new_df["組別"])
print(posthoc.summary())
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =====================================================
# group1 group2 meandiff p-adj   lower    upper  reject
# -----------------------------------------------------
#     A班     B班     -7.5  0.049 -14.9734 -0.0266   True
#     A班     C班     -7.7 0.0419 -15.1734 -0.2266   True
#     B班     C班     -0.2    0.9  -7.6734  7.2734  False
# -----------------------------------------------------

# %% [markdown]
# <font size="5" color="orange">變異數異質</font>

# %%
import pandas as pd
import numpy as np
from scipy.stats import levene
df = pd.DataFrame({
    "A班":[90,85,70,88,77,93,84,88,85,96,95,93,100,94,86,70,87,73,72,69,82,93,81,89,83,80,80,79,62,81],
    "B班":[59,44,73,74,67,93,74,80,95,96,55,73,77,84,96,30,80,23,90,81,72,73,91,99,88,60,79,90,82,71],
    "C班":[90,74,93,60,97,93,94,80,85,86,95,54,27,74,26,70,70,77,10,31,83,43,65,77,78,72,71,82,93,70]
})

statistic, p_value=levene(df["A班"], df["B班"], df["C班"])
print('statistic:%.2f'%statistic)
print('p_value:%.2f'%p_value)
# Out:
# statistic:3.93
# p_value:0.02

# %% [markdown]
# <font size="4" color="red"> 根據同質性檢定發現，樣本之間變異數有顯著差異(p<.05)，因此使用Welch’s Anova進行後續的分析與探討： </font>

# %%
import pingouin as pg
new_df = pd.melt(df, var_name='班級', value_name='分數')
pg.welch_anova(dv='分數', between='班級', data=new_df)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/george/Library/Python/3.6/lib/python/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-57f655eb4ee1>", line 1, in <module>
#     import pingouin as pg
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pingouin/__init__.py", line 7, in <module>
#     from .equivalence import *
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pingouin/equivalence.py", line 5, in <module>
#     from pingouin.parametric import ttest
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pingouin/parametric.py", line 6, in <module>
#     import pandas_flavor as pf
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas_flavor/__init__.py", line 2, in <module>
#     from .register import (
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas_flavor/register.py", line 3
#     from __future__ import annotations
#                                       ^
# SyntaxError: future feature annotations is not defined

# %% [markdown]
# Source: https://medium.com/@jason8410271027/%E5%AD%B8%E7%BF%92%E7%AD%86%E8%A8%98-anova-%E7%90%86%E8%AB%96-python%E5%AF%A6%E4%BD%9C-a86dbbfee60

# %% [markdown]
# <font color="red" size="4"> P554 範例11.1</font>

# %%
import pandas as pd
import numpy as np
from scipy.stats import levene
df = pd.DataFrame({
    "A":[36,26,31,20,34,25],
    "B":[40,29,38,32,39,34],
    "C":[32,18,23,21,33,27]
})

statistic, p_value=levene(df["A"], df["B"], df["C"])
print('statistic:%.2f'%statistic)
print('p_value:%.2f'%p_value)
# Out:
# statistic:0.61
# p_value:0.55

# %% [markdown]
# Source: YT, Performing Python Welch's T Test (Independent Two Sample) in Python, Ryan & Matt Data Science
